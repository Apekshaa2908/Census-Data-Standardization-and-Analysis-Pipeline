# %% [markdown]
# <a href="https://colab.research.google.com/github/Apekshaa2908/Census-Data-Standardization-and-Analysis-Pipeline/blob/main/Census_Data_Standardization_and_Analysis_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Census Data Standardization and Analysis Pipeline**

# %%
# Install necessary libraries
# !pip install pandas
# !pip install docx2txt
# !python -m pip install "pymongo[srv]"
# !pip install mysql-connector-python
# !pip install pymongo
# !pip install flask_sqlalchemy
# !pip install mysql
# !pip instal streamlit
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 441, in run
#     conflicts = self._determine_conflicts(to_install)
# ...

# %%
#import necessary libraries like pandas as numpy
import pandas as pd
import numpy as np
import docx2txt
import pymongo
import pandas as pd
import mysql.connector

# %%
df=pd.read_csv("census_2011.csv") # Read the input file and store it in a DataFrame df

# %%
df.head() # Display the 1st 5 rows of the input file
# Out:
#    District code         State name District name  Population      Male  \
# 0              1  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR        Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR        Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR         Punch         NaN  251899.0
#
#      Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %% [markdown]
# **Task 1: Rename the Column names**
# For uniformity in the datasets and taking into consideration the census year, we need to rename some columns.
# 1. State name  to State/UT
# 2. District name  to District
# 3. Male_Literate to Literate_Male
# 4. Female_Literate to Literate_Female
# 5. Rural_Households  to Households_Rural
# 6. Urban_ Households  to Households_Urban
# 7. Age_Group_0_29 to Young_and_Adult
# 8. Age_Group_30_49 to Middle_Aged
# 9. Age_Group_50 to Senior_Citizen
# 10. Age not stated to Age_Not_Stated

# %%
df.rename(columns = {'State name':'State/UT'},inplace=True)
df.rename(columns = {'District name':'District'},inplace=True)
df.rename(columns = {'Male_Literate':'Literate_Male'},inplace=True)
df.rename(columns = {'Female_Literate':'Literate_Female'},inplace=True)
df.rename(columns = {'Rural_Households':'Households_Rural'},inplace=True)
df.rename(columns = {'Urban_Households':'Households_Urban'},inplace=True)
df.rename(columns = {'Age_Group_0_29':'Young_and_Adult'},inplace=True)
df.rename(columns = {'Age_Group_30_49':'Middle_Aged'},inplace=True)
df.rename(columns = {'Age_Group_50':'Senior_Citizen'},inplace=True)
df.rename(columns = {'Age not stated':'Age_Not_Stated'},inplace=True)

# Rename each column and commiting the changes using inplace

# %%
# Display all the columns that are renamed
df[['State/UT','District','Literate_Male','Literate_Female','Households_Rural','Households_Urban',
    'Young_and_Adult','Middle_Aged','Senior_Citizen','Age_Not_Stated']]
# Out:
#                         State/UT                   District  Literate_Male  \
# 0              JAMMU AND KASHMIR                    Kupwara       282823.0
# 1              JAMMU AND KASHMIR                     Badgam       207741.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)        62834.0
# 3              JAMMU AND KASHMIR                     Kargil        56301.0
# 4              JAMMU AND KASHMIR                      Punch       163333.0
# ..                           ...                        ...            ...
# 635                  PONDICHERRY                       Mahe        16610.0
# 636                  PONDICHERRY                   Karaikal        79903.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars        15397.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman        43186.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman       105794.0
#
# ...

# %% [markdown]
# **Task 2: Rename State/UT Names**
#
# The State/UT names are in all caps in the census data, For uniformity across datasets we use the names so that only the first character of each word in the name is in upper case and the rest are in lower case. However, if the word is “and” then it should be all lowercase.

# %%
# Rename all the State/UT according to the task
def format(state):
  a=state.split()
  b=[]
  for i in a:
    if i.lower()=='and':
      b.append('and')
    else:
      b.append(i.capitalize())
  return ' '.join (b)
df['State/UT'] = df['State/UT'].apply(format)

# %%
# Display all distinct State/UT and check if they are renamed accordingly
df.filter(items=['State/UT']).drop_duplicates()
# Out:
#                         State/UT
# 0              Jammu and Kashmir
# 22              Himachal Pradesh
# 34                        Punjab
# 54                    Chandigarh
# 55                   Uttarakhand
# 68                       Haryana
# 89                  Nct Of Delhi
# 98                     Rajasthan
# 131                Uttar Pradesh
# 202                        Bihar
# 240                       Sikkim
# 244            Arunachal Pradesh
# 260                     Nagaland
# 271                      Manipur
# 280                      Mizoram
# 288                      Tripura
# 292                    Meghalaya
# 299                        Assam
# 326                  West Bengal
# 345                    Jharkhand
# 369                       Orissa
# 399                 Chhattisgarh
# 417               Madhya Pradesh
# 467                      Gujarat
# 493                Daman and Diu
# 495       Dadra and Nagar Haveli
# 496                  Maharashtra
# ...

# %% [markdown]
# **Task 3: New State/UT formation**

# %% [markdown]
# In 2014 Telangana was formed after it split from Andhra Pradesh, The districts that were included in Telangana are stored in Data/Telangana.txt . Read the text file and Rename the State/UT From “Andhra Pradesh” to “Telangana” for the given districts.

# %%
telangana_districts = docx2txt.process("Telangana.docx")

# %%
# Function to change the State/UT according to the District
def update(district):
  if district['State/UT'] == 'Andhra Pradesh' and district['District'] in telangana_districts:
    return 'Telangana'
  return district['State/UT']

df['State/UT'] = df.apply(update, axis=1)

# %%
# To check if they are changed accordingly
df1=df[df['State/UT'].str.contains('Telangana')]
df1.filter(items=['State/UT', 'District']).drop_duplicates()
# Out:
#       State/UT     District
# 531  Telangana     Adilabad
# 532  Telangana    Nizamabad
# 533  Telangana   Karimnagar
# 534  Telangana        Medak
# 535  Telangana    Hyderabad
# 536  Telangana   Rangareddy
# 537  Telangana  Mahbubnagar
# 538  Telangana     Nalgonda
# 539  Telangana     Warangal
# 540  Telangana      Khammam

# %% [markdown]
# In 2019 Ladakh was formed after it split from Jammu and Kashmir, which included the districts Leh and Kargil.  Rename the State/UT From “Jammu and Kashmir” to “Ladakh” for the given districts.

# %%
## List Leh and Kargil and stored in variable ladakh_districts
ladakh_districts = ['Leh(Ladakh)','Kargil']

# %%
# Function to change the State/UT according to the District
def updated(districts):
  if districts['State/UT'] == 'Jammu and Kashmir' and districts['District'] in ladakh_districts:
    return 'Ladakh'
  return districts['State/UT']

df['State/UT'] = df.apply(updated, axis=1)

# %%
# To check if they are changed accordingly
df2=df[df['State/UT'].str.contains('Ladakh')]
df2.filter(items=['State/UT', 'District']).drop_duplicates()
# Out:
#   State/UT     District
# 2   Ladakh  Leh(Ladakh)
# 3   Ladakh       Kargil

# %% [markdown]
# **Task 4: Find and process Missing Data**

# %% [markdown]
# Find and store the percentage of data missing for each column.

# %%
Population = df['Population'].isnull().sum() * 100 / len(df)
Male = df['Male'].isnull().sum() *100 / len(df)
Female = df['Female'].isnull().sum() *100 /len(df)

Literate = df['Literate'].isnull().sum() * 100 / len(df)
Literate_Male = df['Literate_Male'].isnull().sum() * 100 / len(df)
Literate_Female = df['Literate_Female'].isnull().sum() * 100 / len(df)

SC = df['SC'].isnull().sum() * 100 / len(df)
Male_SC= df['Male_SC'].isnull().sum() * 100 / len(df)
Female_SC = df['Female_SC'].isnull().sum() * 100 / len(df)

ST = df['ST'].isnull().sum() * 100 / len(df)
Male_SC= df['Male_ST'].isnull().sum() * 100 / len(df)
Female_SC = df['Female_ST'].isnull().sum() * 100 / len(df)

Workers = df['Workers'].isnull().sum() * 100 / len(df)
Male_Workers= df['Male_Workers'].isnull().sum() * 100 / len(df)
Female_Workers= df['Female_Workers'].isnull().sum() * 100 / len(df)

Main_Workers = df['Main_Workers'].isnull().sum() * 100 / len(df)
Non_Workers= df['Non_Workers'].isnull().sum() * 100 / len(df)
Cultivator_Workers= df['Cultivator_Workers'].isnull().sum() * 100 / len(df)
Agricultural_Workers = df['Agricultural_Workers'].isnull().sum() * 100 / len(df)
Household_Workers= df['Household_Workers'].isnull().sum() * 100 / len(df)
Other_Workers= df['Other_Workers'].isnull().sum() * 100 / len(df)

Hindus = df['Hindus'].isnull().sum() * 100 / len(df)
Muslims= df['Muslims'].isnull().sum() * 100 / len(df)
Christians= df['Christians'].isnull().sum() * 100 / len(df)
Sikhs = df['Sikhs'].isnull().sum() * 100 / len(df)
Buddhists= df['Buddhists'].isnull().sum() * 100 / len(df)
Jains= df['Jains'].isnull().sum() * 100 / len(df)
Others_Religions = df['Others_Religions'].isnull().sum() * 100 / len(df)
Religion_Not_Stated = df['Religion_Not_Stated'].isnull().sum() * 100 / len(df)

Total_Education = df['Total_Education'].isnull().sum() * 100 / len(df)
Literate_Education = df['Literate_Education'].isnull().sum() * 100 / len(df)
Illiterate_Education = df['Illiterate_Education'].isnull().sum() * 100 / len(df)

Households = df['Households'].isnull().sum() * 100 / len(df)
Households_Rural = df['Households_Rural'].isnull().sum() * 100 / len(df)
Households_Urban = df['Households_Urban'].isnull().sum() * 100 / len(df)

# %%
# Print the percentage of each column
print(f"Population: {Population:.2f}%")
print(f"Male: {Male:.2f}%")
print(f"Female: {Female:.2f}%")

print(f"Literate: {Literate:.2f}%")
print(f"Literate_Male: {Literate_Male:.2f}%")
print(f"Literate_Female: {Literate_Female:.2f}%")

print(f"SC: {SC:.2f}%")
print(f"Male_SC: {Male_SC:.2f}%")
print(f"Female_SC: {Female_SC:.2f}%")

print(f"ST: {SC:.2f}%")
print(f"Male_ST: {Male_SC:.2f}%")
print(f"Female_ST: {Female_SC:.2f}%")

print(f"Workers: {SC:.2f}%")
print(f"Male_Workers: {Male_SC:.2f}%")
print(f"Female_Workers: {Female_SC:.2f}%")

print(f"Main_Workers: {Main_Workers:.2f}%")
print(f"Non_Workers: {Non_Workers:.2f}%")
print(f"Cultivator_Workers: {Cultivator_Workers:.2f}%")
print(f"Agricultural_Workers: {Agricultural_Workers:.2f}%")
print(f"Household_Workers: {Household_Workers:.2f}%")
print(f"Other_Workers: {Other_Workers:.2f}%")

print(f"Hindus: {Hindus:.2f}%")
print(f"Muslims: {Muslims:.2f}%")
print(f"Christians: {Christians:.2f}%")
print(f"Sikhs: {Sikhs:.2f}%")
print(f"Buddhists: {Buddhists:.2f}%")
print(f"Jains: {Jains:.2f}%")
print(f"Others_Religions: {Others_Religions:.2f}%")
print(f"Religion_Not_Stated: {Religion_Not_Stated:.2f}%")

print(f"Total_Education: {Total_Education:.2f}%")
print(f"Literate_Education: {Literate_Education:.2f}%")
print(f"Illiterate_Education: {Illiterate_Education:.2f}%")

print(f"Households: {Households:.2f}%")
print(f"Households_Rural: {Population:.2f}%")
print(f"Households_Urban: {Population:.2f}%")

# %%
# Apply necessary formulas
df['Population'] = df['Population'].fillna(df['Male'] + df['Female'])
df['Male'] = df['Male'].fillna(df['Population'] - df['Female'])
df['Female'] = df['Female'].fillna(df['Population'] - df['Male'])
df['Population'] = df['Population'].fillna(df['Middle_Aged'] + df['Senior_Citizen']+df['Age_Not_Stated']+df['Young_and_Adult'])

df['Literate'] = df['Literate'].fillna(df['Literate_Male'] + df['Literate_Female'])
df['Literate_Male'] = df['Literate_Male'].fillna(df['Literate'] - df['Literate_Female'])
df['Literate_Female'] = df['Literate_Female'].fillna(df['Literate'] - df['Literate_Male'])

df['SC'] = df['SC'].fillna(df['Male_SC'] + df['Female_SC'])
df['Female_SC'] = df['Female_SC'].fillna(df['SC'] - df['Male_SC'])
df['Male_SC'] = df['Male_SC'].fillna(df['SC'] - df['Female_SC'])

df['ST'] = df['ST'].fillna(df['Male_ST'] + df['Female_ST'])
df['Female_ST'] = df['Female_ST'].fillna(df['ST'] - df['Male_ST'])
df['Male_ST'] = df['Male_ST'].fillna(df['ST'] - df['Female_ST'])

df['Workers'] = df['Workers'].fillna(df['Male_Workers'] + df['Female_Workers'])
df['Female_Workers'] = df['Female_Workers'].fillna(df['Workers'] - df['Male_Workers'])
df['Male_Workers'] = df['Male_Workers'].fillna(df['Workers'] - df['Female_Workers'])

df["Main_Workers"]= df['Main_Workers'].fillna(df['Population']-(df["Non_Workers"]+ df["Cultivator_Workers"]+ df["Agricultural_Workers"]+ df["Household_Workers"]+ df["Other_Workers"]))
df["Non_Workers"]= df['Non_Workers'].fillna(df['Population']-(df["Main_Workers"]+ df["Cultivator_Workers"]+ df["Agricultural_Workers"]+ df["Household_Workers"]+ df["Other_Workers"]))
df["Cultivator_Workers"]= df['Cultivator_Workers'].fillna(df['Population']-(df["Non_Workers"]+ df["Main_Workers"]+ df["Agricultural_Workers"]+ df["Household_Workers"]+ df["Other_Workers"]))
df["Agricultural_Workers"]= df['Agricultural_Workers'].fillna(df['Population']-(df["Non_Workers"]+ df["Cultivator_Workers"]+ df["Main_Workers"]+ df["Household_Workers"]+ df["Other_Workers"]))
df["Household_Workers"]= df['Household_Workers'].fillna(df['Population']-(df["Non_Workers"]+ df["Cultivator_Workers"]+ df["Agricultural_Workers"]+ df["Main_Workers"]+ df["Other_Workers"]))
df["Other_Workers"]= df['Other_Workers'].fillna(df['Population']-(df["Non_Workers"]+ df["Cultivator_Workers"]+ df["Agricultural_Workers"]+ df["Household_Workers"]+ df["Main_Workers"]))

df["Hindus"]= df["Hindus"].fillna(df["Population"]-(df["Muslims"]+ df["Christians"]+ df["Sikhs"]+ df["Buddhists"]+ df["Jains"]+ df["Others_Religions"]+ df["Religion_Not_Stated"]))
df["Muslims"]= df["Muslims"].fillna(df["Population"]-(df["Hindus"]+ df["Christians"]+ df["Sikhs"]+ df["Buddhists"]+ df["Jains"]+ df["Others_Religions"]+ df["Religion_Not_Stated"]))
df["Christians"]= df["Christians"].fillna(df["Population"]-(df["Muslims"]+ df["Hindus"]+ df["Sikhs"]+ df["Buddhists"]+ df["Jains"]+ df["Others_Religions"]+ df["Religion_Not_Stated"]))
df["Sikhs"]= df["Sikhs"].fillna(df["Population"]-(df["Muslims"]+ df["Christians"]+ df["Hindus"]+ df["Buddhists"]+ df["Jains"]+ df["Others_Religions"]+ df["Religion_Not_Stated"]))
df["Buddhists"]= df["Buddhists"].fillna(df["Population"]-(df["Muslims"]+ df["Christians"]+ df["Sikhs"]+ df["Hindus"]+ df["Jains"]+ df["Others_Religions"]+ df["Religion_Not_Stated"]))
df["Jains"]= df["Jains"].fillna(df["Population"]-(df["Muslims"]+ df["Christians"]+ df["Sikhs"]+ df["Buddhists"]+ df["Hindus"]+ df["Others_Religions"]+ df["Religion_Not_Stated"]))
df["Others_Religions"]= df["Others_Religions"].fillna(df["Population"]-(df["Muslims"]+ df["Christians"]+ df["Sikhs"]+ df["Buddhists"]+ df["Jains"]+ df["Hindus"]+ df["Religion_Not_Stated"]))
df["Religion_Not_Stated"]= df["Religion_Not_Stated"].fillna(df["Population"]-(df["Muslims"]+ df["Christians"]+ df["Sikhs"]+ df["Buddhists"]+ df["Jains"]+ df["Others_Religions"]+ df["Hindus"]))

df["Total_Education"] = df['Total_Education'].fillna(df["Literate_Education"]+df["Illiterate_Education"])
df["Literate_Education"] = df['Literate_Education'].fillna(df["Total_Education"]-df["Illiterate_Education"])
df["Illiterate_Education"] = df['Illiterate_Education'].fillna(df["Total_Education"]-df["Literate_Education"])

df['Households'] = df['Households'].fillna (df['Households_Rural']+df['Households_Urban'])
df['Households_Rural'] = df['Households_Rural'].fillna (df['Households']-df['Households_Urban'])
df['Households_Urban'] = df['Households_Urban'].fillna (df['Households']-df['Households_Rural'])

# %%
#Find the percentage of eah column after applying formulas
Population = df['Population'].isnull().sum() * 100 / len(df)
Male = df['Male'].isnull().sum() *100 / len(df)
Female = df['Female'].isnull().sum() *100 /len(df)

Literate = df['Literate'].isnull().sum() * 100 / len(df)
Literate_Male = df['Literate_Male'].isnull().sum() * 100 / len(df)
Literate_Female = df['Literate_Female'].isnull().sum() * 100 / len(df)

SC = df['SC'].isnull().sum() * 100 / len(df)
Male_SC= df['Male_SC'].isnull().sum() * 100 / len(df)
Female_SC = df['Female_SC'].isnull().sum() * 100 / len(df)

ST = df['ST'].isnull().sum() * 100 / len(df)
Male_SC= df['Male_ST'].isnull().sum() * 100 / len(df)
Female_SC = df['Female_ST'].isnull().sum() * 100 / len(df)

Workers = df['Workers'].isnull().sum() * 100 / len(df)
Male_Workers= df['Male_Workers'].isnull().sum() * 100 / len(df)
Female_Workers= df['Female_Workers'].isnull().sum() * 100 / len(df)

Main_Workers = df['Main_Workers'].isnull().sum() * 100 / len(df)
Non_Workers= df['Non_Workers'].isnull().sum() * 100 / len(df)
Cultivator_Workers= df['Cultivator_Workers'].isnull().sum() * 100 / len(df)
Agricultural_Workers = df['Agricultural_Workers'].isnull().sum() * 100 / len(df)
Household_Workers= df['Household_Workers'].isnull().sum() * 100 / len(df)
Other_Workers= df['Other_Workers'].isnull().sum() * 100 / len(df)

Hindus = df['Hindus'].isnull().sum() * 100 / len(df)
Muslims= df['Muslims'].isnull().sum() * 100 / len(df)
Christians= df['Christians'].isnull().sum() * 100 / len(df)
Sikhs = df['Sikhs'].isnull().sum() * 100 / len(df)
Buddhists= df['Buddhists'].isnull().sum() * 100 / len(df)
Jains= df['Jains'].isnull().sum() * 100 / len(df)
Others_Religions = df['Others_Religions'].isnull().sum() * 100 / len(df)
Religion_Not_Stated = df['Religion_Not_Stated'].isnull().sum() * 100 / len(df)

Total_Education = df['Total_Education'].isnull().sum() * 100 / len(df)
Literate_Education = df['Literate_Education'].isnull().sum() * 100 / len(df)
Illiterate_Education = df['Illiterate_Education'].isnull().sum() * 100 / len(df)

Households = df['Households'].isnull().sum() * 100 / len(df)
Households_Rural = df['Households_Rural'].isnull().sum() * 100 / len(df)
Households_Urban = df['Households_Urban'].isnull().sum() * 100 / len(df)

# %%
# Print the percentage of each column
print(f"Population: {Population:.2f}%")
print(f"Male: {Male:.2f}%")
print(f"Female: {Female:.2f}%")

print(f"Literate: {Literate:.2f}%")
print(f"Literate_Male: {Literate_Male:.2f}%")
print(f"Literate_Female: {Literate_Female:.2f}%")

print(f"SC: {SC:.2f}%")
print(f"Male_SC: {Male_SC:.2f}%")
print(f"Female_SC: {Female_SC:.2f}%")

print(f"ST: {SC:.2f}%")
print(f"Male_ST: {Male_SC:.2f}%")
print(f"Female_ST: {Female_SC:.2f}%")

print(f"Workers: {SC:.2f}%")
print(f"Male_Workers: {Male_SC:.2f}%")
print(f"Female_Workers: {Female_SC:.2f}%")

print(f"Main_Workers: {Main_Workers:.2f}%")
print(f"Non_Workers: {Non_Workers:.2f}%")
print(f"Cultivator_Workers: {Cultivator_Workers:.2f}%")
print(f"Agricultural_Workers: {Agricultural_Workers:.2f}%")
print(f"Household_Workers: {Household_Workers:.2f}%")
print(f"Other_Workers: {Other_Workers:.2f}%")

print(f"Hindus: {Hindus:.2f}%")
print(f"Muslims: {Muslims:.2f}%")
print(f"Christians: {Christians:.2f}%")
print(f"Sikhs: {Sikhs:.2f}%")
print(f"Buddhists: {Buddhists:.2f}%")
print(f"Jains: {Jains:.2f}%")
print(f"Others_Religions: {Others_Religions:.2f}%")
print(f"Religion_Not_Stated: {Religion_Not_Stated:.2f}%")

print(f"Total_Education: {Total_Education:.2f}%")
print(f"Literate_Education: {Literate_Education:.2f}%")
print(f"Illiterate_Education: {Illiterate_Education:.2f}%")

print(f"Households: {Households:.2f}%")
print(f"Households_Rural: {Population:.2f}%")
print(f"Households_Urban: {Population:.2f}%")
# Out:
# Population: 0.16%
# Male: 0.16%
# Female: 0.00%
# Literate: 0.31%
# Literate_Male: 0.31%
# Literate_Female: 0.31%
# SC: 0.62%
# Male_SC: 0.47%
# Female_SC: 0.47%
# ST: 0.62%
# Male_ST: 0.47%
# Female_ST: 0.47%
# Workers: 0.62%
# Male_Workers: 0.47%
# Female_Workers: 0.47%
# Main_Workers: 1.09%
# Non_Workers: 1.41%
# Cultivator_Workers: 0.94%
# Agricultural_Workers: 0.62%
# Household_Workers: 1.09%
# Other_Workers: 1.25%
# Hindus: 0.94%
# Muslims: 0.78%
# Christians: 1.41%
# Sikhs: 1.41%
# Buddhists: 1.41%
# Jains: 1.72%
# Others_Religions: 2.03%
# Religion_Not_Stated: 1.25%
# Total_Education: 0.78%
# Literate_Education: 0.31%
# Illiterate_Education: 0.78%
# Households: 0.78%
# Households_Rural: 0.16%
# Households_Urban: 0.16%

# %%
#Save Data to MongoDB
df_dict =df.to_dict('records')

# %%
# MongoDB connection
mongo_client = pymongo.MongoClient('mongodb+srv://vjapekshaa:1234@cluster0.khtcelp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
mongo_db = mongo_client['Census_Data']
mongo_collection = mongo_db['Census']  # Replace with your actual collection name

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://vjapekshaa:1234@cluster0.khtcelp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
mongo_client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    mongo_client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Create Database
mongo_db = mongo_client['Census_Data']

# %%
# Create collection
mongo_collection = mongo_db['Census']

# %%
# Insert the data in your collection
mongo_collection.insert_many(df_dict)
# Out:
# InsertManyResult([ObjectId('6659d3093ace7aee8e3c2e74'), ObjectId('6659d3093ace7aee8e3c2e75'), ObjectId('6659d3093ace7aee8e3c2e76'), ObjectId('6659d3093ace7aee8e3c2e77'), ObjectId('6659d3093ace7aee8e3c2e78'), ObjectId('6659d3093ace7aee8e3c2e79'), ObjectId('6659d3093ace7aee8e3c2e7a'), ObjectId('6659d3093ace7aee8e3c2e7b'), ObjectId('6659d3093ace7aee8e3c2e7c'), ObjectId('6659d3093ace7aee8e3c2e7d'), ObjectId('6659d3093ace7aee8e3c2e7e'), ObjectId('6659d3093ace7aee8e3c2e7f'), ObjectId('6659d3093ace7aee8e3c2e80'), ObjectId('6659d3093ace7aee8e3c2e81'), ObjectId('6659d3093ace7aee8e3c2e82'), ObjectId('6659d3093ace7aee8e3c2e83'), ObjectId('6659d3093ace7aee8e3c2e84'), ObjectId('6659d3093ace7aee8e3c2e85'), ObjectId('6659d3093ace7aee8e3c2e86'), ObjectId('6659d3093ace7aee8e3c2e87'), ObjectId('6659d3093ace7aee8e3c2e88'), ObjectId('6659d3093ace7aee8e3c2e89'), ObjectId('6659d3093ace7aee8e3c2e8a'), ObjectId('6659d3093ace7aee8e3c2e8b'), ObjectId('6659d3093ace7aee8e3c2e8c'), ObjectId('6659d3093ace7aee8e3c
# ...

# %%
# Fetch data from MongoDB
mongo_data = list(mongo_collection.find())

# %%
# Convert MongoDB data to DataFrame
df_mongo = pd.DataFrame(mongo_data)

# %%
df_mongo.columns.to_list()
# Out:
# ['_id',
#  'District code',
#  'State/UT',
#  'District',
#  'Population',
#  'Male',
#  'Female',
#  'Literate',
#  'Literate_Male',
#  'Literate_Female',
#  'SC',
#  'Male_SC',
#  'Female_SC',
#  'ST',
#  'Male_ST',
#  'Female_ST',
#  'Workers',
#  'Male_Workers',
#  'Female_Workers',
#  'Main_Workers',
#  'Marginal_Workers',
#  'Non_Workers',
#  'Cultivator_Workers',
#  'Agricultural_Workers',
#  'Household_Workers',
#  'Other_Workers',
#  'Hindus',
#  'Muslims',
#  'Christians',
#  'Sikhs',
#  'Buddhists',
#  'Jains',
#  'Others_Religions',
#  'Religion_Not_Stated',
#  'LPG_or_PNG_Households',
#  'Housholds_with_Electric_Lighting',
#  'Households_with_Internet',
#  'Households_with_Computer',
#  'Households_Rural',
#  'Households_Urban',
#  'Households',
#  'Below_Primary_Education',
#  'Primary_Education',
#  'Middle_Education',
#  'Secondary_Education',
#  'Higher_Education',
#  'Graduate_Education',
#  'Other_Education',
#  'Literate_Education',
#  'Illiterate_Education',
# ...

# %%
# Drop the MongoDB _id field if exists
if '_id' in df_mongo.columns:
    df_mongo = df_mongo.drop(columns=['_id'])

# %%
# Insert the updated data in a variable
df_mongodb = df_mongo

# %%
from sqlalchemy import create_engine, inspect
from sqlalchemy.types import VARCHAR, Integer
import pandas as pd

# MySQL connection parameters
mysql_host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com"
mysql_port = 4000
mysql_user = "45HzHwJUFfX4nQz.root"
mysql_password = "NBGV0JkKMrrtdC4I"
mysql_db = "Census_Data"

# MySQL connection string
connection_string = f"mysql+mysqlconnector://{mysql_user}:{mysql_password}@{mysql_host}:{mysql_port}/{mysql_db}"

# Create SQLAlchemy engine
engine = create_engine(connection_string)

# Sample DataFrame
df_mongodb = df_mongo

# Function to map DataFrame dtypes to SQL types
def sqlcol(df_mongo):
    type_df = {}
    for i, j in zip(df_mongo.columns, df_mongo.dtypes):
        if "object" in str(j):
            type_df.update({i: VARCHAR(length=50)})
        elif "int" in str(j):
            type_df.update({i: Integer()})
        elif "float" in str(j):
            type_df.update({i: Integer()})  # Change to Float() if needed
    return type_df

# Shorten column names if they exceed the maximum length allowed by MySQL
max_length = 64
shortened_columns = {col: col[:max_length] for col in df_mongodb.columns}

# Rename columns in the DataFrame
df_mongodb.rename(columns=shortened_columns, inplace=True)

# Get SQL column types
op_dtype = sqlcol(df_mongodb)

# Inspect the engine
inspector = inspect(engine)

# Check if table exists and create if not
if not inspector.has_table("census"):
    df_mongodb.to_sql("census", con=engine, if_exists='replace', index=False, dtype=op_dtype)

print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
# Get SQL column types
op_dtype = sqlcol(df_mongo)
print(op_dtype)
# Out:
# {'District code': Integer(), 'State/UT': VARCHAR(length=50), 'District': VARCHAR(length=50), 'Population': Integer(), 'Male': Integer(), 'Female': Integer(), 'Literate': Integer(), 'Literate_Male': Integer(), 'Literate_Female': Integer(), 'SC': Integer(), 'Male_SC': Integer(), 'Female_SC': Integer(), 'ST': Integer(), 'Male_ST': Integer(), 'Female_ST': Integer(), 'Workers': Integer(), 'Male_Workers': Integer(), 'Female_Workers': Integer(), 'Main_Workers': Integer(), 'Marginal_Workers': Integer(), 'Non_Workers': Integer(), 'Cultivator_Workers': Integer(), 'Agricultural_Workers': Integer(), 'Household_Workers': Integer(), 'Other_Workers': Integer(), 'Hindus': Integer(), 'Muslims': Integer(), 'Christians': Integer(), 'Sikhs': Integer(), 'Buddhists': Integer(), 'Jains': Integer(), 'Others_Religions': Integer(), 'Religion_Not_Stated': Integer(), 'LPG_or_PNG_Households': Integer(), 'Housholds_with_Electric_Lighting': Integer(), 'Households_with_Internet': Integer(), 'Households_with_Compute
# ...

# %%
# Connection to mysql
connection = mysql.connector.connect(
  user='45HzHwJUFfX4nQz.root',
  password='NBGV0JkKMrrtdC4I',
  host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
  port="4000")
mycursor = connection.cursor(buffered=True)

# %%
# Select Database
mycursor.execute("USE census_data")

# %%
# 1. Total population of each district
st.title('Total Popluation of Each District')
query = """SELECT District, SUM(Population) as Population FROM Census GROUP BY District ORDER BY District"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Total Population of Each District")
st.dataframe(df)

# %%
# 2. Literate males and females are there in each district
st.title('Literate males and females are there in each district')
query = """SELECT District, SUM(Literate_Male) AS Literate_Male, SUM(Literate_Female) AS Literate_Female FROM Census GROUP BY District"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Literate males and females are there in each district")
st.dataframe(df)

# %%
# 3. Percentage of workers (both male and female) in each district
mycursor.execute('SELECT District,(Male_Workers/Workers)*100 as Male_Workers,(Female_Workers/Workers)*100 as Female_Workers FROM Census')
st.title('Percentage of workers (both male and female) in each district')
query = """SELECT District, SUM(Population) as Population FROM Census GROUP BY District ORDER BY District"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Percentage of workers (both male and female) in each district")
st.dataframe(df)

# %%
# 4. Fetch the data for households with access to LPG or PNG as cooking fuel in each district
st.title('Households with access to LPG or PNG as cooking fuel in each district')
query = """SELECT District, LPG_or_PNG_Households FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Households with access to LPG or PNG as cooking fuel in each district")
st.dataframe(df)

# %%
# 5. Fetch the religious composition of each district
st.title('Religious composition of each district')
query = """SELECT District, Hindus, Muslims, Christians, Sikhs, Buddhists, Jains, Others_Religions, Religion_Not_Stated FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Religious composition of each district")
st.dataframe(df)

# %%
# 6. Fetch the households with internet access in each district
st.title('Households with internet access in each district')
query = """SELECT District, Households_with_Internet FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Households with internet access in each district")
st.dataframe(df)

# %%
# 7.The educational attainment distribution (below primary, primary, middle, secondary, etc.) in each district
st.title('Educational attainment distribution')
query = """SELECT District,Below_Primary_Education,Primary_Education,Middle_Education,Secondary_Education,Higher_Education,Graduate_Education,Other_Education FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Educational attainment distribution")
st.dataframe(df)

# %%
# 8.Households have access to various modes of transportation (bicycle, car, radio, television, etc.) in each district
st.title('Households have access to various modes of transportation')
query = """SELECT District, Households_with_Bicycle, Households_with_Car_Jeep_Van, Households_with_Scooter_Motorcycle_Moped FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Households have access to various modes of transportation")
st.dataframe(df)

# %%
# 9. The condition of occupied census houses (dilapidated, with separate kitchen, with bathing facility, with latrine facility, etc.) in each district
st.title('The condition of occupied census houses')
query = """SELECT District, Condition_of_occupied_census_houses_Dilapidated_Households as Dilapidated, Households_with_separate_kitchen_Cooking_inside_house as Seperate_Kitchen, Having_bathing_facility_Total_Households as Bathing_Facility, Having_latrine_facility_within_the_premises_Total_Households as Laterine_within_premisis, Not_having_latrine_facility_within_the_premises_Alternative_sour as Laterine_outside_premisis_Alternate_sources FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The condition of occupied census houses")
st.dataframe(df)

# %%
# 10. The household size distributed (1 person, 2 persons, 3-5 persons, etc.) in each district
st.title('The household size distributed')
query = """SELECT District, Household_size_1_person_Households as 1_Person, Household_size_2_persons_Households as 2_Persons,  Household_size_3_persons_Households as 3_Persons, Household_size_4_persons_Households as 4_Persons, Household_size_5_persons_Households as 5_Persons, Household_size_6_8_persons_Households as 6to8_Persons, Household_size_9_persons_and_above_Households as 9_and_more_Persons FROM Census"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The household size distributed")
st.dataframe(df)

# %%
# 11. The total number of households in each state
st.title('The total number of households in each state')
query = """SELECT `State/UT`, SUM(Households)as Total_Households FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The total number of households in each state")
st.dataframe(df)

# %%
# 12. Household having laterine facility within permises in each state
st.title('Household having laterine facility within permises in each state')
query = """SELECT `State/UT`, SUM(Having_latrine_facility_within_the_premises_Total_Households) as On_Premisis_Laterine FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Household having laterine facility within permises in each state")
st.dataframe(df)

# %%
# 13. The average household size in each state
st.title('The average household size in each state')
query = """SELECT `State/UT`, AVG(Household_size_1_person_Households) as "1-Person", AVG(Household_size_2_persons_Households) as "2-Persons", AVG(Household_size_3_persons_Households) as "3-Persons", AVG(Household_size_4_persons_Households) as "4-Persons", Avg(Household_size_5_persons_Households) as "5-Persons", AVG(Household_size_6_8_persons_Households) as "6to8-Persons", AVG(Household_size_9_persons_and_above_Households) as "9 and more Persons" FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The average household size in each state")
st.dataframe(df)

# %%
# 14. Households are owned versus rented in each state
st.title('Households are owned versus rented in each state')
query = """SELECT `State/UT`, SUM(Ownership_Owned_Households) as "Owned",SUM(Ownership_Rented_Households) as "Rented" FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Households are owned versus rented in each state")
st.dataframe(df)

# %%
# 15. The distribution of different types of latrine facilities (pit latrine, flush latrine, etc.) in each state
st.title('The distribution of different types of latrine facilities')
query = """SELECT `State/UT`, SUM(Type_of_latrine_facility_Pit_latrine_Households) as "Pit Laterine",SUM(type_of_latrine_facility_Other_latrine_Households) as "Other Laterine",SUM(Type_of_latrine_facility_Night_soil_disposed_into_open_drain_Hou) as "Night Soil",SUM(Type_of_latrine_facility_Flush_pour_flush_latrine_connected_to_o) as "Flush" FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The distribution of different types of latrine facilities")
st.dataframe(df)

# %%
# 16. Households have access to drinking water sources near the premises in each state
st.title('Households have access to drinking water sources near the premises in each state')
query = """SSELECT `State/UT`, SUM(Location_of_drinking_water_source_Within_the_premises_Households) as "Households" FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Households have access to drinking water sources near the premises in each state")
st.dataframe(df)

# %%
# 17. The average household income distribution in each state based on the power parity categories
st.title('The average household income distribution in each state based on the power parity categories')
query = """SELECT `State/UT`, AVG(Power_Parity_Less_than_Rs_45000) as "income < 45000", AVG(Power_Parity_Rs_45000_150000) as "income between 45000 to 150000", AVG(Power_Parity_Rs_150000_330000) as "income between 150000 to 330000", AVG(Power_Parity_Rs_330000_545000) as "income between 330000 to 545000", AVG(Power_Parity_Above_Rs_545000) as "income > 545000" FROM Census GROUP BY`State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The average household income distribution in each state based on the power parity categories")
st.dataframe(df)

# %%
# 18. The percentage of married couples with different household sizes in each state
st.title('The percentage of married couples with different household sizes in each state')
query = """SELECT `State/UT`, (SUM(Married_couples_1_Households)/SUM(Married_couples_None_Households +Married_couples_1_Households+Married_couples_2_Households+Married_couples_3_or_more_Households))*100 as "1"  ,(SUM(Married_couples_2_Households)/SUM(Married_couples_None_Households +Married_couples_1_Households+Married_couples_2_Households+Married_couples_3_or_more_Households))*100 as"2" ,(SUM(Married_couples_3_or_more_Households)/SUM(Married_couples_None_Households+Married_couples_1_Households+Married_couples_2_Households+Married_couples_3_or_more_Households))*100 as "3" FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The percentage of married couples with different household sizes in each state")
st.dataframe(df)

# %%
# 19. Households fall below the poverty line in each state based on the power parity categories
st.title('Households fall below the poverty line in each state based on the power parity categories')
query = """SELECT `State/UT`,SUM(Power_Parity_Less_than_Rs_45000) as "Households"  FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("Households fall below the poverty line in each state based on the power parity categories")
st.dataframe(df)

# %%
# 20. The overall literacy rate (percentage of literate population) in each state
mycursor.execute('')
# 1. Total population of each district
st.title('The overall literacy rate in each state')
query = """SELECT `State/UT`, (SUM(Literate_Education)/SUM(Total_Education))*100 as Literacy_Rate FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The overall literacy rate in each state")
st.dataframe(df)

# %%
! wget -q -O - ipv4.icanhazip.com
! streamlit run Census.py & npx localtunnel --port 8501

# %%
# Sample Execution
# %%writefile Census.py
import streamlit as st
import mysql.connector
import pandas as pd

# Function to establish a connection to the database
def get_connection():
    return mysql.connector.connect(
        user='45HzHwJUFfX4nQz.root',
        password='NBGV0JkKMrrtdC4I',
        host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
        port="4000"
    )

# Function to fetch data from the database
def fetch_data(query):
    connection = get_connection()
    mycursor = connection.cursor(buffered=True)
    mycursor.execute("USE census_data")
    mycursor.execute(query)
    rows = mycursor.fetchall()
    column_names = [i[0] for i in mycursor.description]
    mycursor.close()
    connection.close()
    return pd.DataFrame(rows, columns=column_names)

# 11. The total number of households in each state
st.title('The total number of households in each state')
query = """SELECT `State/UT`, SUM(Households)as Total_Households FROM Census GROUP BY `State/UT`"""
df = fetch_data(query)

# Display the data in Streamlit
st.write("The total number of households in each state")
st.dataframe(df)

# %%
! wget -q -O - ipv4.icanhazip.com
! streamlit run Census.py & npx localtunnel --port 8501
